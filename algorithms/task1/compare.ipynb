# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from algorithms.task1.utils import load_and_plot

# %%
load_and_plot('dictionary_len', rotation=45)
# Out:
# <AxesSubplot: xlabel='dictionary_len', ylabel='time[ns]'>

# %%
load_and_plot('pattern_len')
# Out:
# <AxesSubplot: xlabel='pattern_len', ylabel='time[ns]'>

# %%
load_and_plot('text_len')
# Out:
# <AxesSubplot: xlabel='text_len', ylabel='time[ns]'>

# %%
df = pd.read_csv('wyniki.csv')

fig, axs = plt.subplots(3, 1, figsize=(7, 21))

for col, ax in zip(('pattern_len', 'text_len', 'dictionary_len', 'python_naive_search'), axs):
    sns.pointplot(
        data=df, x=col, y="time[ns]", hue="function", errorbar=None, ax=ax
    )
