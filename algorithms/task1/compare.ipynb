# %%
from algorithms.task1.utils import load_and_plot

# %%
load_and_plot('dictionary_len', rotate=90, font_scale=1.5)

# %%
load_and_plot('pattern_len')

# %%
load_and_plot('text_len', rotate=90, font_scale=1.5)
