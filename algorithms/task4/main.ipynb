# %%
from algorithms.task4.graph import Graph

# %%
graph = Graph.from_file("sample.graph")
graph.image("1", "4")

# %%
Graph.from_list_of_edges(
    [
        ("1", "2", 20),
        ("1", "3", 15),
        ("1", "4", 50),
        ("2", "3", 8),
        ("2", "5", 20),
        ("2", "6", 10),
        ("3", "2", 1),
        ("3", "6", 12),
        ("4", "2", 14),
        ("5", "6", 10),
        ("5", "2", 25),
        ("5", "4", 19),
        ("6", "2", 8),
        ("6", "3", 10),
        ("6", "5", 2),
    ]
).image("1", "4")
