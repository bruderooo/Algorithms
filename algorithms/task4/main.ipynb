# %%
from algorithms.task4.graph import Graph
from algorithms.task4.time_graph import TimeGraph

# %%
graph = Graph.from_file("sample.graph")
graph.image("1", "5")
# Out:
# {'2': '1', '3': '1', '4': '1', '6': '3', '5': '6'}

# %%
Graph.from_list_of_edges(
    [
        ("1", "2", 20),
        ("1", "3", 15),
        ("1", "4", 50),
        ("2", "3", 8),
        ("2", "5", 20),
        ("2", "6", 10),
        ("3", "2", 1),
        ("3", "6", 12),
        ("4", "2", 14),
        ("5", "6", 10),
        ("5", "2", 25),
        ("5", "4", 19),
        ("6", "2", 8),
        ("6", "3", 10),
        ("6", "5", 2),
    ]
).image("1", "4")

# %%
TimeGraph.from_list_of_edges(
    [
        ("1", "2", 10, 5, 10),
        ("1", "3", 15, 6, 8),
        ("2", "3", 4, 8, 16),
        ("2", "4", 15, 8, 16),
        ("3", "4", 6, 18, 24),
        ("4", "1", 30, 62),
    ]
).image("1", "4")
